# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Dataframes

# %%
# Setting Variables
path = r'C:\Users\Saikat Halder\Documents\CareerFoundry\Data Immersion\Achievement 4\Instacart Basket Analysis 01182024'
# Importing Merged Dataframe
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_all_dataframes_new_variables.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered         price_label  \
# 0                     3.0                  5          0  Mid range products
# 1                    20.0                  1          1  Mid range products
# 2                     6.0                 20          0  Mid range products
# 3                     0.0                 10          0  Mid range products
# 4                     9.0                 11          1  Mid range products
#
#     busiest_days busiest_period_of_day
# 0  Regulary busy           Most orders
# 1  Regulary busy           Most orders
# 2   Busiest days        Average orders
# 3   Slowest days           Most orders
# 4   Slowest days           Most orders

# %% [markdown]
# # Creating Subset

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered         price_label  \
# 0                     3.0                  5          0  Mid range products
# 1                    20.0                  1          1  Mid range products
# 2                     6.0                 20          0  Mid range products
# 3                     0.0                 10          0  Mid range products
# 4                     9.0                 11          1  Mid range products
#
#     busiest_days busiest_period_of_day
# 0  Regulary busy           Most orders
# 1  Regulary busy           Most orders
# 2   Busiest days        Average orders
# 3   Slowest days           Most orders
# 4   Slowest days           Most orders

# %%
df.dtypes
# Out:
# product_id                  int64
# product_name               object
# aisle_id                    int64
# department_id               int64
# prices                    float64
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_day_of_week           int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# add_to_cart_order           int64
# reordered                   int64
# price_label                object
# busiest_days               object
# busiest_period_of_day      object
# dtype: object

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df.groupby('product_name')

# %% [markdown]
# # Average number of orders per user across each department

# %%
# 1. Split the data into groups based on 'department_id'
# 2. Apply the agg() function to each group to obtain the mean values for the 'order_numer' column

df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# This produces the same result
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %% [markdown]
# # Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# # Aggregating Data with transform()

# %% [markdown]
# ## Creating a loyalty flag column

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby (['user_id']) ['order_number'].transform(np.max)
# Out:
# C:\Users\Saikat Halder\AppData\Local\Temp\ipykernel_21888\4022601473.py:1: FutureWarning: The provided callable <function amax at 0x0000021C94D38180> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby (['user_id']) ['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                  6                 11
# 1    1977647      138            30                  6                 17
# 2     389851      709             2                  0                 21
# 3     652770      764             1                  3                 13
# 4    1813452      764             3                  4                 17
# ..       ...      ...           ...                ...                ...
# 95    602103    10831             8                  3                 11
# 96     49629    11119            18                  1                 14
# 97    317888    11186            13                  5                 16
# 98    682486    11243            16                  3                 13
# 99   2861386    11448            10                  2                 15
#
#     days_since_prior_order  add_to_cart_order  reordered         price_label  \
# 0                      3.0                  5          0  Mid range products
# 1                     20.0                  1          1  Mid range products
# 2                      6.0                 20          0  Mid range products
# 3                      0.0                 10          0  Mid range products
# 4                      9.0                 11          1  Mid range products
# ..                     ...                ...        ...                 ...
# 95                    23.0                  5          0  Mid range products
# 96                    30.0                  1          0  Mid range products
# 97                     2.0                  8          0  Mid range products
# 98                     0.0                  2          0  Mid range products
# 99                     3.0                  6          0  Mid range products
#
#      busiest_days busiest_period_of_day  max_order
# 0   Regulary busy           Most orders         32
# 1   Regulary busy           Most orders         32
# 2    Busiest days        Average orders          5
# 3    Slowest days           Most orders          3
# 4    Slowest days           Most orders          3
# ..            ...                   ...        ...
# 95   Slowest days           Most orders         10
# 96   Busiest days           Most orders         23
# 97  Regulary busy           Most orders         26
# 98   Slowest days           Most orders         43
# 99  Regulary busy           Most orders         21
#
# [100 rows x 17 columns]

# %%
# Changing the maximum rows shown by Jupytar
pd.options.display.max_rows = None

# %% [markdown]
# ## Deriving Columns with loc()

# %%
# If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer."
# If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Frequency Coount of loyalty Flag
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Verifying column 
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1
